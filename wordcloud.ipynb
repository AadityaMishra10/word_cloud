# %%
# Here are all the installs and imports you will need for your word cloud script and uploader widget

# %pip install wordcloud
# %pip install fileupload
# %pip install ipywidgets
# %jupyter nbextension install --py --user fileupload
# %jupyter nbextension enable --py fileupload

import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys

#/notebooks/C1M6L2_Final_Project_V3.ipynb (LINK FOR THE PROJECT CODE )
# This is the uploader widget

def _upload():

    _upload_widget = fileupload.FileUploadWidget()

    def _cb(change):
        global file_contents
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} kB)'.format(
            filename, len(decoded.read()) / 2 **10))
        file_contents = decoded.getvalue()

    _upload_widget.observe(_cb, names='data')
    display(_upload_widget)

_upload()
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.8.2.2.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (1.24.0)
# Requirement already satisfied: pillow in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
#   Running setup.py install for wordcloud: started
#   Running setup.py install for wordcloud: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: wordcloud is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for wordcloud did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       running install
#       c:\Users\aadit\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\color_from_image.py -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\tokenization.py -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\wordcloud.py -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\_version.py -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\__init__.py -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\__main__.py -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\stopwords -> build\lib.win-amd64-cpython-311\wordcloud
#       copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-cpython-311\wordcloud
#       UPDATING build\lib.win-amd64-cpython-311\wordcloud/_version.py
#       set build\lib.win-amd64-cpython-311\wordcloud/_version.py to '1.8.2.2'
#       running build_ext
#       building 'wordcloud.query_integral_image' extension
#       creating build\temp.win-amd64-cpython-311
#       creating build\temp.win-amd64-cpython-311\Release
#       creating build\temp.win-amd64-cpython-311\Release\wordcloud
#       "C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Ic:\Users\aadit\AppData\Local\Programs\Python\Python311\include -Ic:\Users\aadit\AppData\Local\Programs\Python\Python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt" /Tcwordcloud/query_integral_image.c /Fobuild\temp.win-amd64-cpython-311\Release\wordcloud/query_integral_image.obj
#       query_integral_image.c
#       wordcloud/query_integral_image.c(196): fatal error C1083: Cannot open include file: 'longintrepr.h': No such file or directory
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.29.30133\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> wordcloud
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: fileupload in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (0.1.5)
# Requirement already satisfied: ipywidgets>=5.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from fileupload) (8.0.4)
# Requirement already satisfied: notebook>=4.2 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from fileupload) (6.5.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from fileupload) (5.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipywidgets>=5.1->fileupload) (6.21.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipywidgets>=5.1->fileupload) (8.10.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=5.1->fileupload) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=5.1->fileupload) (3.0.5)
# Requirement already satisfied: jinja2 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (25.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (5.2.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (8.0.2)
# Requirement already satisfied: ipython-genutils in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.2.0)
# Requirement already satisfied: nbformat in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (5.7.3)
# Requirement already satisfied: nbconvert>=5 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (7.2.9)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from notebook>=4.2->fileupload) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from notebook>=4.2->fileupload) (0.5.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.6.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.6)
# Requirement already satisfied: packaging in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (23.0)
# Requirement already satisfied: psutil in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (5.9.4)
# Requirement already satisfied: backcall in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: decorator in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.6.2)
# Requirement already satisfied: colorama in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->fileupload) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.6.1->notebook>=4.2->fileupload) (3.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.6.1->notebook>=4.2->fileupload) (305)
# Requirement already satisfied: jupyter-server>=1.17.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->fileupload) (2.3.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (4.11.2)
# Requirement already satisfied: bleach in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (6.0.0)
# Requirement already satisfied: defusedxml in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (2.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbformat->notebook>=4.2->fileupload) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from nbformat->notebook>=4.2->fileupload) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from terminado>=0.8.3->notebook>=4.2->fileupload) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi->notebook>=4.2->fileupload) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.4.4)
# Requirement already satisfied: websocket-client in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (1.5.1)
# Requirement already satisfied: wcwidth in c:\users\aadit\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=4.2->fileupload) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.2->fileupload) (2.4)
# Requirement already satisfied: webencodings in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.2->fileupload) (0.5.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\aadit\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (2.0.6)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (2.3)
# Requirement already satisfied: uri-template in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.12)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipywidgets in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (8.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipywidgets) (6.21.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipywidgets) (8.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (8.0.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: psutil in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: pyzmq>=20 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: backcall in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: colorama in c:\users\aadit\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (305)
# Requirement already satisfied: wcwidth in c:\users\aadit\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aadit\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\aadit\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\aadit\appdata\local\programs\python\python311\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# UsageError: Line magic function `%jupyter` not found.

# %%
def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just"]
    
    # LEARNER CODE START HERE
    count = {}
    words = file_contents.split()
    for word in words:
        if word in uninteresting_words:
            pass
        else:
            for letter in word:
                if letter in punctuations:
                    letter.replace(punctuations,"")
            if word not in count.keys():
                count[word]=0
            else:
                count[word]+=1
            
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(count)
    return cloud.to_array()
    
    # Display your wordcloud image

myimage = calculate_frequencies(file_contents)
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 32
#      28     return cloud.to_array()
#      30     # Display your wordcloud image
# ---> 32 myimage = calculate_frequencies(file_contents)
#      33 plt.imshow(myimage, interpolation = 'nearest')
#      34 plt.axis('off')
#
# NameError: name 'file_contents' is not defined
